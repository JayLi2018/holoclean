# %%
import pandas as pd
from collections import defaultdict

# %%
df=pd.read_csv('Adult.csv')

# %%
df[:2]
# Out:
#      Age    Workclass     Education       Maritalstatus       Occupation  \
# 0  31-50      Private  Some-college  Married-civ-spouse     Craft-repair
# 1    >50  Federal-gov  Some-college       Never-married  Exec-managerial
#
#   Relationship   Race     Sex HoursPerWeek        Country       Income
# 0      Husband  White    Male           40  United-States  LessThan50K
# 1    Own-child  Black  Female           40  United-States  LessThan50K

# %%
list(df.iloc[0:1,0:1])
# Out:
# ['Age']

# %%
df.iloc[0,0]
# Out:
# '100-200'

# %%
d={}

# %%
list(df['Age'].unique())
# Out:
# ['31-50', '>50', '22-30', '18-21', '<18']

# %%
for c in list(df):
    d[c]=list(df[c].unique())

# %%
d
# Out:
# {'Age': ['31-50', '>50', '22-30', '18-21', '<18'],
#  'Workclass': ['Private',
#   'Federal-gov',
#   'Self-emp-inc',
#   'State-gov',
#   'Self-emp-not-inc',
#   'Local-gov',
#   '?'],
#  'Education': ['Some-college',
#   'Bachelors',
#   'HS-grad',
#   'Prof-school',
#   'Assoc-voc',
#   'Assoc-acdm',
#   '10th',
#   'Masters',
#   '5th-6th',
#   '12th',
#   '11th',
#   'Doctorate',
#   '1st-4th',
#   '7th-8th',
#   '9th'],
#  'Maritalstatus': ['Married-civ-spouse',
#   'Never-married',
#   'Divorced',
#   'Widowed',
#   'Separated',
#   'Married-spouse-absent',
#   'Married-AF-spouse'],
#  'Occupation': ['Craft-repair',
#   'Exec-managerial',
#   'Sales',
#   'Farming-fishing',
#   'Prof-specialty',
#   'Adm-clerical',
#   'Handlers-cleaners',
#   'Other-service',
#   'Machine-op-inspct',
#   '?',
#   'Transport-moving',
#   'Priv-house-serv',
#   'Protective-serv',
#   'Tech-support'],
#  'Relationship': ['Husband',
#   'Own-child',
#   'Not-in-family',
#   'Unmarried',
# ...

# %%
gt_df=pd.DataFrame(dict_list)

# %%
gt_df
# Out:
#         attribute         correct_val  tid
# 0             Age             100-200    0
# 1       Workclass             Private    0
# 2       Education        Some-college    0
# 3   Maritalstatus  Married-civ-spouse    0
# 4      Occupation        Craft-repair    0
# 5    Relationship             Husband    0
# 6            Race               White    0
# 7             Sex                Male    0
# 8    HoursPerWeek                  40    0
# 9         Country       United-States    0
# 10         Income         LessThan50K    0
# 11            Age                 >50    1
# 12      Workclass         Federal-gov    1
# 13      Education        Some-college    1
# 14  Maritalstatus       Never-married    1
# 15     Occupation     Exec-managerial    1
# 16   Relationship           Own-child    1
# 17           Race               Black    1
# 18            Sex              Female    1
# 19   HoursPerWeek                  40    1
# 20        Country       United-States    1
# ...
