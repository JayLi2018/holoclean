# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

l = []

for i in range(0, 1000):
    x = random.randint(1,100)
    d = {'x':x, 'y':list(x**2 + 10 + 10000*np.random.normal(0, 0.1, 1))[0]}
    l.append(d)

df = pd.DataFrame(l)

plt.scatter(x=df['x'], y=df['y'])
plt.xlabel("x")
plt.ylabel("y")
plt.show()
