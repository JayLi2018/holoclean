# %%
# given a list of DCs, and a wrong repair(hand-picked), return the responsibility of the DCs

# %% [markdown]
# ### 1. run holoclean and return wrongly repaired cells

# %%
from examples.holoclean_repair_example import main
import psycopg2
import pandas as pd
import copy
pd.set_option('display.max_rows', None)

# %%
# connection to db 
conn = psycopg2.connect(dbname="holo", user="holocleanuser", password="abcd1234")
cols = ["ProviderNumber","HospitalName","Address1","Address2","Address3","City","State","ZipCode","CountyName","PhoneNumber","HospitalType","HospitalOwner",
        "EmergencyService","Condition","MeasureCode","MeasureName","Score","Sample","Stateavg"]
cur = conn.cursor()
conn.autocommit=True

# %%
# drop preexisted repaired records 
select_old_repairs_q = """
SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES 
WHERE TABLE_NAME LIKE 'airport_repaired_%' AND TABLE_TYPE = 'BASE TABLE'
"""
cur.execute(select_old_repairs_q)

# %%
for records in cur.fetchall():
    drop_q = f"drop table if exists {records[0]}"
    cur.execute(drop_q)

# %%
main(initial_training=True)
# Out:
# 20:02:45 - [DEBUG] - initiating session with parameters: {'db_user': 'holocleanuser', 'db_pwd': 'abcd1234', 'db_host': 'localhost', 'db_name': 'holo', 'threads': 1, 'timeout': 180000, 'seed': 45, 'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 10, 'weight_decay': 0.01, 'momentum': 0.0, 'batch_size': 1, 'weak_label_thresh': 0.99, 'domain_thresh_1': 0, 'domain_thresh_2': 0, 'max_domain': 10000, 'cor_strength': 0.6, 'nb_cor_strength': 0.8, 'feature_norm': False, 'weight_norm': False, 'estimator_epochs': 3, 'estimator_batch_size': 32, 'verbose': True, 'bias': False, 'print_fw': True, 'debug_mode': False}
# 20:02:45 - [WARNING] - Dropping the following null column from the dataset: 'Address2'
# 20:02:45 - [WARNING] - Dropping the following null column from the dataset: 'Address3'
# 20:02:45 - [ INFO] - Loaded 1000 rows with 18000 cells
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [DEBUG] - Time to create index: 0.00 secs
# 20:02:45 - [ INFO] - DONE Loading hospital.csv
# 20:02:45 - [DEBUG] - Time to load dataset: 0.20 secs
# 20:02:45 - [DEBUG] - OPENED constraints file successfully
# 20:02:45 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.City,t2.City)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.City,t2.City)
# 20:02:45 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1."City"=t2."City"
# 20:02:45 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalName,t2.HospitalName)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalName,t2.HospitalName)
# 20:02:45 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:45 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalName,t2.HospitalName)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."HospitalName"<>t2."HospitalName"
# 20:02:45 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:45 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:45 - [DEBUG] - DONE parsing predicate: IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName" AND t1."ProviderNumber"<>t2."ProviderNumber"
# 20:02:45 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:45 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:45 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:45 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."City"<>t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."Stateavg"<>t2."Stateavg"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."MeasureName"<>t2."MeasureName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."State"<>t2."State"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalOwner"=t2."HospitalOwner" AND t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode" AND t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName" AND t1."State"<>t2."State"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."City"=t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."City"=t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.CountyName,t2.CountyName)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.CountyName,t2.CountyName)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."CountyName"=t2."CountyName" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber" AND t1."City"<>t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."Address1"=t2."Address1"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."HospitalOwner"<>t2."HospitalOwner"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."EmergencyService"<>t2."EmergencyService"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."Stateavg"=t2."Stateavg"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalOwner"=t2."HospitalOwner" AND t1."EmergencyService"<>t2."EmergencyService" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."CountyName"=t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.Condition,t2.Condition)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.Condition,t2.Condition)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalOwner"=t2."HospitalOwner" AND t1."Condition"=t2."Condition" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."Address1"=t2."Address1"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."State"<>t2."State"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.EmergencyService,t2.EmergencyService)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.EmergencyService,t2.EmergencyService)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalOwner"=t2."HospitalOwner" AND t1."EmergencyService"<>t2."EmergencyService" AND t1."State"<>t2."State"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."City"=t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode" AND t1."MeasureName"<>t2."MeasureName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName" AND t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Address1,t2.Address1)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Address1,t2.Address1)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."PhoneNumber"<>t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.EmergencyService,t2.EmergencyService)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."EmergencyService"<>t2."EmergencyService"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."HospitalOwner"<>t2."HospitalOwner"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName" AND t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.Address1,t2.Address1)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.Address1,t2.Address1)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalName"=t2."HospitalName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."Condition"<>t2."Condition"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalName,t2.HospitalName)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalName,t2.HospitalName)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."CountyName"<>t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode" AND t1."City"=t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."HospitalName"=t2."HospitalName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.Condition,t2.Condition)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.Condition,t2.Condition)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."HospitalOwner"=t2."HospitalOwner"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.Condition,t2.Condition)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."Condition"<>t2."Condition"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."CountyName"=t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.CountyName,t2.CountyName)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.CountyName,t2.CountyName)&EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."City"=t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber" AND t1."CountyName"<>t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.City,t2.City)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."City"<>t2."City"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.ZipCode,t2.ZipCode)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.ZipCode,t2.ZipCode)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Address1,t2.Address1)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Address1,t2.Address1)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1" AND t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalOwner,t2.HospitalOwner)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."HospitalOwner"=t2."HospitalOwner" AND t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."ZipCode"<>t2."ZipCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."ProviderNumber"<>t2."ProviderNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."HospitalName"=t2."HospitalName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ZipCode"=t2."ZipCode" AND t1."CountyName"<>t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode" AND t1."Stateavg"<>t2."Stateavg"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.MeasureCode,t2.MeasureCode)&EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Score,t2.Score)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber" AND t1."Score"=t2."Score"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureName"=t2."MeasureName" AND t1."HospitalOwner"=t2."HospitalOwner"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.CountyName,t2.CountyName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."CountyName"=t2."CountyName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."MeasureCode"=t2."MeasureCode" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.Address1,t2.Address1)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.Address1,t2.Address1)&EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."PhoneNumber"=t2."PhoneNumber"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."ProviderNumber"=t2."ProviderNumber" AND t1."MeasureName"=t2."MeasureName"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Stateavg,t2.Stateavg)&EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Stateavg,t2.Stateavg)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Stateavg"=t2."Stateavg" AND t1."ZipCode"=t2."ZipCode"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.HospitalType,t2.HospitalType)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.State,t2.State)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Address1,t2.Address1)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Address1,t2.Address1)&IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1" AND t1."HospitalType"<>t2."HospitalType"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Address1,t2.Address1)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Address1,t2.Address1)&IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1" AND t1."State"<>t2."State"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Sample,t2.Sample)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Sample"=t2."Sample"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&IQ(t1.EmergencyService,t2.EmergencyService)&EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1."Address1"=t2."Address1"
# 20:02:46 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.Address1,t2.Address1)
# 20:02:46 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# ...
# 20:04:45 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Address1'   AND t1."Address1" != t2._value_ with id 2
# 20:04:45 - [DEBUG] - Time to execute query with id 2: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'City'   AND t1."City" != t2._value_ with id 3
# 20:04:45 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'State'   AND t1."State" != t2._value_ with id 4
# 20:04:45 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'ZipCode'   AND t1."ZipCode" != t2._value_ with id 5
# 20:04:45 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'CountyName'   AND t1."CountyName" != t2._value_ with id 6
# 20:04:45 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'PhoneNumber'   AND t1."PhoneNumber" != t2._value_ with id 7
# 20:04:45 - [DEBUG] - Time to execute query with id 7: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'HospitalType'   AND t1."HospitalType" != t2._value_ with id 8
# 20:04:45 - [DEBUG] - Time to execute query with id 8: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'HospitalOwner'   AND t1."HospitalOwner" != t2._value_ with id 9
# 20:04:45 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'EmergencyService'   AND t1."EmergencyService" != t2._value_ with id 10
# 20:04:45 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Condition'   AND t1."Condition" != t2._value_ with id 11
# 20:04:45 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'MeasureCode'   AND t1."MeasureCode" != t2._value_ with id 12
# 20:04:45 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'MeasureName'   AND t1."MeasureName" != t2._value_ with id 13
# 20:04:45 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Score'   AND t1."Score" != t2._value_ with id 14
# 20:04:45 - [DEBUG] - Time to execute query with id 14: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Sample'   AND t1."Sample" != t2._value_ with id 15
# 20:04:45 - [DEBUG] - Time to execute query with id 15: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Stateavg'   AND t1."Stateavg" != t2._value_ with id 16
# 20:04:45 - [DEBUG] - Time to execute query with id 16: 0.00 secs
# 20:04:45 - [DEBUG] - Time to execute 17 queries: 0.08 secs
# 20:04:45 - [DEBUG] - Time to execute query: 0.00 secs
# 20:04:45 - [DEBUG] - Preparing to execute 17 queries.
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'ProviderNumber'       AND t1."ProviderNumber" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 0
# 20:04:45 - [DEBUG] - Time to execute query with id 0: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalName'       AND t1."HospitalName" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 1
# 20:04:45 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Address1'       AND t1."Address1" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 2
# 20:04:45 - [DEBUG] - Time to execute query with id 2: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'City'       AND t1."City" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 3
# 20:04:45 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'State'       AND t1."State" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 4
# 20:04:45 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'ZipCode'       AND t1."ZipCode" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 5
# 20:04:45 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'CountyName'       AND t1."CountyName" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 6
# 20:04:45 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'PhoneNumber'       AND t1."PhoneNumber" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 7
# 20:04:45 - [DEBUG] - Time to execute query with id 7: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalType'       AND t1."HospitalType" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 8
# 20:04:45 - [DEBUG] - Time to execute query with id 8: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalOwner'       AND t1."HospitalOwner" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 9
# 20:04:45 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'EmergencyService'       AND t1."EmergencyService" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 10
# 20:04:45 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Condition'       AND t1."Condition" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 11
# 20:04:45 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'MeasureCode'       AND t1."MeasureCode" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 12
# 20:04:45 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'MeasureName'       AND t1."MeasureName" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 13
# 20:04:45 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Score'       AND t1."Score" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 14
# 20:04:45 - [DEBUG] - Time to execute query with id 14: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Sample'       AND t1."Sample" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 15
# 20:04:45 - [DEBUG] - Time to execute query with id 15: 0.00 secs
# 20:04:45 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Stateavg'       AND t1."Stateavg" != t2._value_ ) as errors, inf_values_dom as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND errors._value_ = repairs.rv_value with id 16
# 20:04:45 - [DEBUG] - Time to execute query with id 16: 0.00 secs
# 20:04:45 - [DEBUG] - Time to execute 17 queries: 0.08 secs
# 20:04:45 - [DEBUG] - Time to execute query: 0.00 secs
# 20:04:45 - [DEBUG] - weak label statistics:
# 20:04:45 - [DEBUG] -     is_clean  cell_status  is_inferred  init = grdth init = inferred  \
# 0   False     0            True         False         False
# 1   False     0            True         False         False
# 2   False     0            True         False         True
# 3   False     0            True         True          False
# 4   False     0            True         True          True
# 5   False     1            True         False         False
# 6   False     1            True         False         True
# 7   False     1            True         False         True
# 8   False     1            True         True          False
# 9   False     1            True         True          True
# 10  False     2            True         False         True
# 11  False     2            True         True          True
# 12  True      0            False        True          None
# 13  True      1            False        True          None
#
#     w. label = init  w. label = grdth w. label = inferred infer = grdth  count
# 0   True             False             False               False         5
# 1   True             False             False               True          35
# 2   True             False             True                False         95
# 3   True             True              False               False         43
# 4   True             True              True                True          14071
# 5   False            True              True                True          263
# 6   False            False             False               False         7
# 7   False            True              False               False         73
# 8   False            False             True                False         16
# 9   False            False             False               True          172
# 10  True             False             True                False         31
# 11  True             True              True                True          1760
# 12  True             True              None                None          181
# 13  False            False             None                None          21
# 20:04:45 - [ INFO] - Precision = 0.82, Recall = 0.59, Repairing Recall = 0.59, F1 = 0.68, Repairing F1 = 0.68, Detected Errors = 509, Total Errors = 509, Correct Repairs = 298, Total Repairs = 362, Total Repairs on correct cells (Grdth present) = 59, Total Repairs on incorrect cells (Grdth present) = 303
# 20:04:45 - [DEBUG] - Time to generate report: 0.21 secs

# %%
### 2. run holoclean and return wrongly repaired ddcells

# %%
union_sql = """
SELECT 'before_clean' AS type, * from  hospital
union all 
SELECT 'after_clean' AS type, * from hospital_repaired
order by _tid_
"""
df_union_before_and_after = pd.read_sql(union_sql, conn)

# %%
df_union_before_and_after
# Out:
#               type  _tid_ ProviderNumber                      HospitalName  \
# 0      after_clean      0          10018  callahan eye foundation hospital
# 1     before_clean      0          10018  callahan eye foundation hospital
# 2      after_clean      1          10018  callahan eye foundation hospital
# 3     before_clean      1          10018  callahan eye foundation hospital
# 4     before_clean      2          10018  callahan eye foundation hospital
# 5      after_clean      2          10018  callahan eye foundation hospital
# 6     before_clean      3          10018  callahan eye foundation hospital
# 7      after_clean      3          10018  callahan eye foundation hospital
# 8     before_clean      4          10018  callahan eye foundation hospital
# 9      after_clean      4          10018  callahan eye foundation hospital
# 10     after_clean      5          10018  callahan eye foundation hospital
# 11    before_clean      5          10018  callahan eye foundation hospital
# 12     after_clean      6          10018  callahan eye foundation hospital
# 13    before_clean      6          10018  callahan eye foundation hospital
# 14    before_clean      7          10018  callahan eye foundation hospital
# 15     after_clean      7          10018  callahan eye foundation hospital
# 16     after_clean      8          10019    helen keller memorial hospital
# 17    before_clean      8          10019    helen keller memorial hospital
# 18     after_clean      9          10019    helen keller memorial hospital
# 19    before_clean      9          10019    helen keller memorial hospital
# 20     after_clean     10          10019    helen keller memorial hospital
# 21    before_clean     10          10019    helen keller memorial hospital
# 22     after_clean     11          10019    helen keller memorial hospital
# 23    before_clean     11          10019    helen keller memorial hospital
# 24    before_clean     12          10019    helen keller memorial hospital
# 25     after_clean     12          10019    helen keller memorial hospital
# 26     after_clean     13          10019    helen keller memorial hospital
# 27    before_clean     13          1xx19    helen keller memorial hospital
# 28     after_clean     14          10019    helen keller memorial hospital
# 29    before_clean     14          10019    helen keller memorial hospital
# ...            ...    ...            ...                               ...
# 1970   after_clean    985          10050                st vincents blount
# 1971  before_clean    985          10050                st vincents blount
# 1972   after_clean    986          10050                st vincents blount
# 1973  before_clean    986          10050                st vincents blount
# 1974   after_clean    987          10050                st vincents blount
# 1975  before_clean    987          10050                st vincents bxount
# 1976  before_clean    988          10050                st vincents blount
# 1977   after_clean    988          10050                st vincents blount
# 1978  before_clean    989          10050                st vincents blount
# 1979   after_clean    989          10050                st vincents blount
# 1980   after_clean    990          10050                st vincents blount
# 1981  before_clean    990          10050                st vincents blount
# 1982  before_clean    991          10050                st vincents blount
# 1983   after_clean    991          10050                st vincents blount
# 1984   after_clean    992          10050                st vincents blount
# 1985  before_clean    992          10050                st vincents blount
# 1986  before_clean    993          10050                st vincents blount
# 1987   after_clean    993          10050                st vincents blount
# 1988   after_clean    994          10050                st vincents blount
# 1989  before_clean    994          10050                st vincents blount
# 1990   after_clean    995          10050                st vincents blount
# 1991  before_clean    995          10050                st vincents blount
# 1992  before_clean    996          10050                st vincents blount
# 1993   after_clean    996          10050                st vincents blount
# 1994   after_clean    997          10050                st vincents blount
# 1995  before_clean    997          10050                st vincents blount
# 1996  before_clean    998          10050                st vincents blount
# 1997   after_clean    998          10050                st vincents blount
# 1998  before_clean    999          10050                st vincents blount
# 1999   after_clean    999          10050                st vincents blount
#
#                           Address1        City State ZipCode CountyName  \
# 0             1720 university blvd  birmingham    al   35233  jefferson
# 1             1720 university blvd  birmingham    al   35233  jefferson
# 2             1720 university blvd  birmingham    al   35233  jefferson
# 3             1720 university blvd  birmingham    al   35233  jefferson
# 4             1720 university blvd  birmingham    al   35233  jefferson
# 5             1720 university blvd  birmingham    al   35233  jefferson
# 6             1720 university blvd  birminghxm    al   35233  jefferson
# 7             1720 university blvd  birmingham    al   35233  jefferson
# 8             1720 university blvd  birmingham    al   35233  jefferson
# 9             1720 university blvd  birmingham    al   35233  jefferson
# 10            1720 university blvd  birmingham    al   35233  jefferson
# 11            1720 university blvd  birmingham    al   35233  jefferson
# 12            1720 university blvd  birmingham    al   35233  jefferson
# 13            1720 university blvd  birmingham    al   35233  jefferson
# 14            1720 university blvd  birmingxam    al   35233  jefferson
# 15            1720 university blvd  birmingham    al   35233  jefferson
# 16    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 17    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 18    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 19    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 20    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 21    1300 south montgomery avenue   sheffxeld    al   35660  jefferson
# 22    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 23    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 24    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 25    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 26    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 27    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 28    1300 south montgomery avenue   sheffield    al   35660  jefferson
# 29    1300 south montgomery avenue   sheffield    al   35660  jefferson
# ...                            ...         ...   ...     ...        ...
# 1970           150 gilbreath drive     oneonta    al   35121     blount
# 1971           150 gilbreath drive     onxonta    al   35121     blount
# 1972           150 gilbreath drive     oneonta    al   35121     blount
# 1973           150 gilxreath drive     oneonta    al   35121     blount
# 1974           150 gilbreath drive     oneonta    al   35121     blount
# 1975           150 gilbreath drive     oneonta    al   35121     blount
# 1976           150 gilbreath drive     oneonta    al   35121     blount
# 1977           150 gilbreath drive     oneonta    al   35121     blount
# 1978           150 gilbreath drive     oneonta    al   35121     blount
# 1979           150 gilbreath drive     oneonta    al   35121     blount
# 1980           150 gilbreath drive     oneonta    al   35121     blount
# 1981           150 gilbreath drive     oneonta    al   35121     blount
# 1982           150 gilbreath drive     oneonta    al   35121     blount
# 1983           150 gilbreath drive     oneonta    al   35121     blount
# 1984           150 gilbreath drive     oneonta    al   35121     blount
# 1985           150 gilbreath drive     oneonta    al   35121     blount
# 1986           150 gilbreath drive     oneonta    al   35121     blount
# 1987           150 gilbreath drive     oneonta    al   35121     blount
# 1988           150 gilbreath drive     oneonta    al   35121     blount
# 1989           150 gilbreath drive     oneonta    al   35121     blount
# 1990           150 gilbreath drive     oneonta    al   35121     blount
# 1991           150 gilbreath drive     oneonta    al   35121     blount
# 1992           150 gilbreath drive     oneonta    al   35121     blount
# 1993           150 gilbreath drive     oneonta    al   35121     blount
# 1994           150 gilbreath drive     oneonta    al   35121     blount
# 1995           150 gilbreath drive     oneonta    al   35121     blount
# 1996           150 gilbreath drive     oneonta    al   35121     blount
# 1997           150 gilbreath drive     oneonta    al   35121     blount
# 1998           150 gilbreath drive     oneonta    al   35121     blount
# 1999           150 gilbreath drive     oneonta    al   35121     blount
#
#      PhoneNumber          HospitalType  \
# 0     2053258100  acute care hospitals
# 1     2053258100  acute care hospitals
# 2     2053258100  acute care hospitals
# 3     2053258100  acute care hospitals
# 4     2053258100  acute care hospitals
# 5     2053258100  acute care hospitals
# 6     2053258100  acute care hospitals
# 7     2053258100  acute care hospitals
# 8     2053258100  acute care hospitals
# 9     2053258100  acute care hospitals
# 10    2053258100  acute care hospitals
# 11    2053258100  acute care hospitals
# 12    2053258100  acute care hospitals
# 13    2053258100  acute care hospitals
# 14    2053258100  acute care hospitals
# 15    2053258100  acute care hospitals
# 16    2563864556  acute care hospitals
# 17    2563864556  acute care hospitals
# 18    2563864556  acute care hospitals
# 19    2563864556  acute care hospitals
# 20    2563864556  acute care hospitals
# 21    2563864556  acute care hospitals
# 22    2563864556  acute care hospitals
# 23    2563864556  acute care hospitals
# 24    2563864556  acute care hospitals
# 25    2563864556  acute care hospitals
# 26    2563864556  acute care hospitals
# 27    2563864556  acute care hospitals
# 28    2563864556  acute care hospitals
# 29    2563864556  acute care hospitals
# ...          ...                   ...
# 1970  2052743000  acute care hospitals
# 1971  2052743000  acute care hospitals
# 1972  2052743000  acute care hospitals
# 1973  2052743000  acute care hospitals
# 1974  2052743000  acute care hospitals
# 1975  2052743000  acute care hospitals
# 1976  2052743000  acute care hospitals
# 1977  2052743000  acute care hospitals
# 1978  2052743000  acute care hospitals
# 1979  2052743000  acute care hospitals
# 1980  2052743000  acute care hospitals
# 1981  2052743000  acute care hospitals
# 1982  2052743000  acute care hospitals
# 1983  2052743000  acute care hospitals
# 1984  2052743000  acute care hospitals
# 1985  2052743000  acute care hospitals
# 1986  2052743000  acute care hospitals
# 1987  2052743000  acute care hospitals
# 1988  2052743000  acute care hospitals
# 1989  2052743000  acute care hospitals
# 1990  2052743000  acute care hospitals
# 1991  2052743000  acute care hospitals
# 1992  2052743000  acute care hospitals
# 1993  2052743000  acute care hospitals
# 1994  2052743000  acute care hospitals
# 1995  2052743000  acute care hospitals
# 1996  2052743000  acute care hospitals
# 1997  2052743000  acute care hospitals
# 1998  2052743000  acute care hospitals
# 1999  2052743000  acute care hospitals
#
#                                     HospitalOwner EmergencyService  \
# 0                  voluntary non-profit - private              yes
# 1                  voluntary non-profit - private              yes
# 2                  voluntary non-profit - private              yes
# 3                  voluntary non-profit - private              yes
# 4                  voluntary non-profit - private              yes
# 5                  voluntary non-profit - private              yes
# 6                  voluntary non-profit - private              yes
# 7                  voluntary non-profit - private              yes
# 8                  voluntary non-profit - private              yes
# 9                  voluntary non-profit - private              yes
# 10                 voluntary non-profit - private              yes
# 11                 voluntary non-profit - private              yes
# 12                 voluntary non-profit - private              yes
# 13                 voluntary non-profit - private              yes
# 14                 voluntary non-profit - private              yes
# 15                 voluntary non-profit - private              yes
# 16    government - hospital district or authority              yes
# 17    government - hospital district or authority              yes
# 18    government - hospital district or authority              yes
# 19    government - hospital district or authority              yes
# 20    government - hospital district or authority              yes
# 21    government - hospital district or authority              yes
# 22    government - hospital district or authority              yes
# 23    government - hospital district or authority              yes
# 24    government - hospital district or authority              yes
# 25    government - hospital district or authority              yes
# 26    government - hospital district or authority              yes
# 27    government - hospital district or authority              yes
# 28    government - hospital district or authority              yes
# 29    government - hospital district or authority              yes
# ...                                           ...              ...
# 1970               voluntary non-profit - private              yes
# 1971               voluntary non-profit - private              yes
# 1972               voluntary non-profit - private              yes
# 1973               voluntary non-profit - private              yes
# 1974               voluntary non-profit - private              yes
# 1975               voluntary non-profit - private              yes
# 1976               voluntary non-profit - private              yes
# 1977               voluntary non-profit - private              yes
# 1978               voluntary non-profit - private              yes
# 1979               voluntary non-profit - private              yes
# 1980               voluntary non-profit - private              yes
# 1981               voluntary non-profit - private              yes
# 1982               voluntary non-profit - private              yes
# 1983               voluntary non-profit - private              yes
# 1984               voluntary non-profit - private              yes
# 1985               voluntary non-profit - private              yes
# 1986               voluntary non-profit - private              yes
# 1987               voluntary non-profit - private              yes
# 1988               voluntary non-profit - private              yes
# 1989               voluntary non-profit - private              yes
# 1990               voluntary non-profit - private              yes
# 1991               voluntary non-profit - private              yes
# 1992               voluntary non-profit - private              yes
# 1993               voluntary non-profit - private              yes
# 1994               voluntary non-profit - private              yes
# 1995               voluntary non-profit - private              yes
# 1996               voluntary non-profit - private              yes
# 1997               voluntary non-profit - private              yes
# 1998               voluntary non-profit - private              yes
# 1999               voluntary non-profit - private              yes
#
#                           Condition  MeasureCode  \
# 0     surgical infection prevention  scip-card-2
# 1     surgical infection prevention  scip-card-2
# 2     surgical infection prevention   scip-inf-1
# 3     surgical infection prevention   scip-inf-1
# 4     surgical infection prevention   scip-inf-2
# 5     surgical infection prevention   scip-inf-2
# 6     surgical infection prevention   scip-inf-3
# 7     surgical infection prevention   scip-inf-3
# 8     surgical infection prevention   scip-inf-4
# 9     surgical infection prevention   scip-inf-4
# 10    surgical infection prevention   scip-inf-6
# 11    surgical infection prevention   scip-inf-6
# 12    surgical infection prevention   scip-vte-1
# 13    surgical infection prevention   scip-vte-1
# 14    surgical infection prevention   scip-vte-2
# 15    surgical infection prevention   scip-vte-2
# 16                     heart attack        ami-1
# 17                     heart attack        ami-1
# 18                     heart attack        ami-2
# 19                     heart attack        ami-2
# 20                     heart attack        ami-3
# 21                     heart attack        ami-3
# 22                     heart attack        ami-4
# 23                     heart attack        ami-4
# 24                     heart attack        ami-5
# 25                     heart attack        ami-5
# 26                     heart attack       ami-7a
# 27                     heart attack       ami-7a
# 28                     heart attack       ami-8a
# 29                     heart attack       ami-8a
# ...                             ...          ...
# 1970                   heart attack       ami-7a
# 1971                   heart attack       ami-7a
# 1972                   heart attack       ami-8a
# 1973                   heart attack       ami-8a
# 1974                  heart failure         hf-1
# 1975                  heart failure         hf-1
# 1976                  heart failure         hf-2
# 1977                  heart failure         hf-2
# 1978                  heart failure         hf-3
# 1979                  heart failure         hf-3
# 1980                  heart failure         hf-4
# 1981                  heart failure         hf-4
# 1982                      pneumonia         pn-2
# 1983                      pneumonia         pn-2
# 1984                      pneumonia        pn-3b
# 1985                      pneumonia        pn-3b
# 1986                      pneumonia         pn-4
# 1987                      pneumonia         pn-4
# 1988                      pneumonia        pn-5c
# 1989                      pneumonia        pn-5c
# 1990                      pneumonia         pn-6
# 1991                      pneumonia         pn-6
# 1992                      pneumonia         pn-7
# 1993                      pneumonia         pn-7
# 1994  surgical infection prevention  scip-card-2
# 1995  surgical infection prevention  scip-card-2
# 1996  surgical infection prevention   scip-inf-1
# 1997  surgical infection prevention   scip-inf-1
# 1998  surgical infection prevention   scip-inf-2
# 1999  surgical infection prevention   scip-inf-2
#
#                                             MeasureName  Score        Sample  \
# 0     surgery patients who were taking heart drugs c...  _nan_         _nan_
# 1     surgery patients who were taking heart drugs c...  _nan_         _nan_
# 2     surgery patients who were given an antibiotic ...  _nan_         _nan_
# 3     surgery patients who were given an antibiotic ...  _nan_         _nan_
# 4     surgery patients who were given the  right kin...  _nan_         _nan_
# 5     surgery patients who were given the  right kin...  _nan_         _nan_
# 6     surgery patients whose preventive antibiotics ...  _nan_         _nan_
# 7     surgery patients whose preventive antibiotics ...  _nan_         _nan_
# 8     all heart surgery patients whose blood sugar (...  _nan_         _nan_
# 9     all heart surgery patients whose blood sugar (...  _nan_         _nan_
# 10    surgery patients needing hair removed from the...  _nan_         _nan_
# 11    surgery patients needing hair removed from the...  _nan_         _nan_
# 12    surgery patients whose doctors ordered treatme...  _nan_         _nan_
# 13    surgery patients whose doctors ordered treatme...  _nan_         _nan_
# 14    patients who got treatment  at the right time ...  _nan_         _nan_
# 15    patients who got treatment  at the right time ...  _nan_         _nan_
# 16       heart attack patients given aspirin at arrival    97%   33 patients
# 17       heart attack patients given aspirin at arrival    97%   33 patients
# 18     heart attack patients given aspirin at discharge    92%   13 patients
# 19     heart attack patients given aspirin at discharge    92%   13 patients
# 20    heart attack patients given ace inhibitor or a...   100%    4 patients
# 21    heart attack patients given ace inhibitor or a...    75%    4 patients
# 22    heart attack patients given smoking cessation ...   100%    4 patients
# 23    heart attack patients given smoking cessation ...   100%    4 patients
# 24    heart attack patients given beta blocker at di...    86%   14 patients
# 25    heart attack patients given beta blocker at di...    86%   14 patients
# 26    heart attack patients given fibrinolytic medic...  _nan_    0 patients
# 27    heart attack patients given fibrinolytic medic...  _nan_    0 patients
# 28    heart attack patients given pci within 90 minu...  _nan_    0 patients
# 29    heart attack patients given pci within 90 minu...  _nan_    0 patients
# ...                                                 ...    ...           ...
# 1970  heart attack patients given fibrinolytic medic...  _nan_    0 patients
# 1971  heart attack patients given fibrinolytic medic...  _nan_    0 patients
# 1972  heart attack patients given pci within 90 minu...  _nan_    0 patients
# 1973  heart attack patients given pci within 90 minu...  _nan_    0 patients
# 1974  heart failure patients given discharge instruc...    50%   24 patients
# 1975  heart failure patients given discharge instruc...    50%   24 patients
# 1976  heart failure patients given an evaluation of ...    85%   34 patients
# 1977  heart failure patients given an evaluation of ...   100%   34 patients
# 1978  heart failure patients given ace inhibitor or ...   100%    7 patients
# 1979  heart failure patients given ace inhibitor or ...   100%    7 patients
# 1980  heart failure patients given smoking cessation...   100%    7 patients
# 1981  heart failure patients given smoking cessation...    43%    7 patients
# 1982  pneumonia patients assessed and given pneumoco...    74%   92 patients
# 1983  pneumonia patients assessed and given pneumoco...    74%   92 patients
# 1984  pneumonia patients whose initial emergency roo...    83%  103 patients
# 1985  pneumonia patients whose initial emergency roo...    83%  103 patients
# 1986  pneumonia patients given smoking cessation adv...    83%   29 patients
# 1987  pneumonia patients given smoking cessation adv...    83%   29 patients
# 1988  pneumonia patients given initial antibiotic(s)...    98%  105 patients
# 1989  pneumonia patients given initial antibiotic(s)...    98%  105 patients
# 1990  pneumonia patients given the most appropriate ...    77%   74 patients
# 1991  pneumonia patients given the most appropriate ...    77%   74 patients
# 1992  pneumonia patients assessed and given influenz...    64%   55 patients
# 1993  pneumonia patients assessed and given influenz...    64%   55 patients
# 1994  surgery patients who were taking heart drugs c...   100%    8 patients
# 1995  surgery pxtients who were txking hexrt drugs c...    25%    8 patients
# 1996  surgery patients who were given an antibiotic ...    64%   28 patients
# 1997  surgery patients who were given an antibiotic ...    64%   28 patients
# 1998  surgery patients who were given the  right kin...    88%   25 patients
# 1999  surgery patients who were given the  right kin...    88%   25 patients
#
#             Stateavg
# 0     al_scip-card-2
# 1     al_scip-card-2
# 2      al_scip-inf-1
# 3      al_scip-inf-1
# 4      al_scip-inf-2
# 5      al_scip-inf-2
# 6      al_scip-inf-3
# 7      al_scip-inf-3
# 8      al_scip-inf-4
# 9      al_scip-inf-4
# 10     al_scip-inf-6
# 11     al_scip-inf-6
# 12     al_scip-vte-1
# 13     al_scip-vte-1
# 14     al_scip-vte-2
# 15     al_scip-vte-2
# 16          al_ami-1
# 17          al_ami-1
# 18          al_ami-2
# 19          al_ami-2
# 20          al_ami-3
# 21          al_ami-3
# 22          al_ami-4
# 23          al_ami-4
# 24          al_ami-5
# 25          al_ami-5
# 26         al_ami-7a
# 27         al_ami-7a
# 28         al_ami-8a
# 29         al_ami-8a
# ...              ...
# 1970       al_ami-7a
# 1971       al_ami-7a
# 1972       al_ami-8a
# 1973       al_ami-8a
# 1974         al_hf-1
# 1975         al_hf-1
# 1976         al_hf-2
# 1977         al_hf-2
# 1978         al_hf-3
# 1979         al_hf-3
# 1980         al_hf-4
# 1981         al_hf-4
# 1982         al_pn-2
# 1983         al_pn-2
# 1984        al_pn-3b
# 1985        al_pn-3b
# 1986         al_pn-4
# 1987         al_pn-4
# 1988        al_pn-5c
# 1989        al_pn-5c
# 1990         al_pn-6
# 1991         al_pn-6
# 1992         al_pn-7
# 1993         al_pn-7
# 1994  al_scip-card-2
# 1995  al_scip-card-2
# 1996   al_scip-inf-1
# 1997   al_scip-inf-1
# 1998   al_scip-inf-2
# 1999   al_scip-inf-2
#
# [2000 rows x 19 columns]

# %%
j = 0
for i in range(0,1000):
    if(j%100==0):
        print(j)
    j+=1
    df_row = pd.DataFrame(columns=['type']+cols)
    df_row.loc[0,'type'] = 'ground_truth'
    df_row.loc[0,'_tid_'] = i
    q = f"""
    SELECT * FROM hospital_clean WHERE _tid_={i} 
    """
    df_for_one_row = pd.read_sql(q,conn)
    for index, row in df_for_one_row.iterrows():
        df_row.loc[0, f"{row['_attribute_']}"] = row['_value_']
    df_union_before_and_after = df_union_before_and_after.append(df_row, ignore_index=True)
# Out:
# 0
# /home/jayli/Desktop/holo_env/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
repaired_dict = {x:[] for x in cols}

# %%
# iterate this dataframe to find all wrong predictions and list them to choose
grouped = df_union_before_and_after.groupby('_tid_')
k = 0

for name, group in grouped:
    tid = pd.to_numeric(group.iloc[0]['_tid_'], downcast="integer")
    if(k%100==0):
        print(k)
    for c in cols:
        if(group[group['type']=='after_clean'][c].to_string(index=False)\
           != group[group['type']=='before_clean'][c].to_string(index=False)):
            repaired_dict[c].append(tid)
    k+=1
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
repaired_dict
# Out:
# {'ProviderNumber': [13.0,
#   45.0,
#   81.0,
#   213.0,
#   244.0,
#   253.0,
#   273.0,
#   314.0,
#   360.0,
#   408.0,
#   559.0,
#   608.0,
#   627.0,
#   639.0,
#   645.0,
#   655.0,
#   704.0,
#   721.0,
#   724.0,
#   755.0,
#   780.0,
#   789.0,
#   793.0,
#   859.0,
#   878.0,
#   888.0,
#   933.0,
#   955.0],
#  'HospitalName': [26.0,
#   131.0,
#   171.0,
#   243.0,
#   337.0,
#   384.0,
#   385.0,
#   448.0,
#   532.0,
#   560.0,
#   654.0,
#   697.0,
#   730.0,
#   758.0,
#   765.0,
#   777.0,
#   903.0,
#   921.0,
#   922.0,
#   938.0,
#   962.0,
#   987.0],
#  'Address1': [57.0,
#   94.0,
#   106.0,
#   161.0,
#   175.0,
#   260.0,
#   264.0,
#   275.0,
#   295.0,
#   316.0,
#   334.0,
#   363.0,
#   411.0,
#   415.0,
#   431.0,
#   472.0,
#   484.0,
#   652.0,
#   736.0,
#   767.0,
#   849.0,
#   857.0,
#   915.0,
#   934.0,
#   935.0,
#   945.0,
#   956.0,
#   986.0],
#  'Address2': [],
#  'Address3': [],
#  'City': [3.0,
#   7.0,
#   10.0,
#   56.0,
#   79.0,
#   88.0,
#   93.0,
#   180.0,
#   207.0,
#   212.0,
#   228.0,
#   311.0,
#   367.0,
#   437.0,
#   474.0,
#   485.0,
#   517.0,
#   578.0,
#   590.0,
#   601.0,
#   654.0,
#   690.0,
#   696.0,
#   736.0,
#   756.0,
#   772.0,
#   821.0,
#   895.0,
#   949.0,
#   960.0,
#   968.0,
#   985.0],
#  'State': [83.0, 504.0, 592.0, 791.0],
#  'ZipCode': [44.0,
#   63.0,
#   70.0,
#   137.0,
#   139.0,
#   149.0,
#   157.0,
#   196.0,
#   232.0,
#   267.0,
#   283.0,
#   290.0,
#   325.0,
#   332.0,
#   340.0,
#   366.0,
#   375.0,
#   406.0,
#   420.0,
#   428.0,
#   490.0,
#   499.0,
#   544.0,
#   679.0,
#   685.0,
#   750.0,
#   815.0,
#   923.0],
#  'CountyName': [67.0,
#   72.0,
#   77.0,
#   136.0,
#   216.0,
#   221.0,
#   223.0,
#   227.0,
#   238.0,
#   252.0,
#   312.0,
#   324.0,
#   346.0,
#   456.0,
#   457.0,
#   465.0,
#   502.0,
#   513.0,
#   527.0,
#   540.0,
#   551.0,
#   578.0,
#   590.0,
#   602.0,
#   633.0,
#   672.0,
#   689.0,
#   692.0,
#   698.0,
#   722.0,
#   730.0,
#   752.0,
#   785.0,
#   798.0,
#   895.0,
#   917.0,
#   943.0,
#   966.0],
#  'PhoneNumber': [24.0,
#   36.0,
#   60.0,
#   65.0,
#   101.0,
#   217.0,
#   228.0,
#   247.0,
#   261.0,
#   321.0,
#   342.0,
#   381.0,
#   393.0,
#   471.0,
#   516.0,
#   548.0,
#   561.0,
#   562.0,
#   572.0,
#   593.0,
#   666.0,
#   699.0,
#   713.0,
#   751.0,
#   763.0,
#   824.0,
#   865.0,
#   881.0,
#   883.0,
#   916.0],
#  'HospitalType': [16.0,
#   39.0,
#   98.0,
#   199.0,
#   266.0,
#   280.0,
#   293.0,
#   411.0,
#   453.0,
#   497.0,
#   511.0,
#   588.0,
#   634.0,
#   695.0,
#   705.0,
#   729.0,
#   779.0,
#   782.0,
#   814.0,
#   848.0,
#   877.0,
#   926.0,
#   964.0,
#   976.0],
#  'HospitalOwner': [113.0, 313.0, 449.0, 493.0, 784.0, 846.0],
#  'EmergencyService': [],
#  'Condition': [199.0, 712.0, 851.0],
#  'MeasureCode': [349.0, 391.0, 580.0, 735.0, 788.0],
#  'MeasureName': [111.0,
#   145.0,
#   210.0,
#   219.0,
#   281.0,
#   290.0,
#   346.0,
#   380.0,
#   389.0,
#   473.0,
#   507.0,
#   532.0,
#   541.0,
#   545.0,
#   562.0,
#   612.0,
#   672.0,
#   705.0,
#   706.0,
#   713.0,
#   785.0,
#   802.0,
#   816.0,
#   915.0,
#   997.0],
#  'Score': [10.0,
#   34.0,
#   35.0,
#   54.0,
#   95.0,
#   103.0,
#   120.0,
#   123.0,
#   126.0,
#   128.0,
#   129.0,
#   132.0,
#   135.0,
#   158.0,
#   163.0,
#   164.0,
#   167.0,
#   168.0,
#   171.0,
#   173.0,
#   330.0,
#   336.0,
#   361.0,
#   378.0,
#   390.0,
#   470.0,
#   488.0,
#   509.0,
#   511.0,
#   514.0,
#   569.0,
#   641.0,
#   683.0,
#   695.0,
#   704.0,
#   711.0,
#   718.0,
#   742.0,
#   808.0,
#   834.0,
#   836.0,
#   840.0,
#   844.0,
#   856.0,
#   860.0,
#   862.0,
#   879.0,
#   910.0,
#   940.0,
#   988.0,
#   990.0,
#   997.0],
#  'Sample': [],
#  'Stateavg': [56.0,
#   69.0,
#   193.0,
#   213.0,
#   269.0,
#   334.0,
#   347.0,
#   370.0,
#   387.0,
#   432.0,
#   433.0,
#   435.0,
#   436.0,
#   437.0,
#   438.0,
#   439.0,
#   441.0,
#   442.0,
#   443.0,
#   444.0,
#   445.0,
#   446.0,
#   448.0,
#   449.0,
#   450.0,
#   451.0,
#   477.0,
#   555.0,
#   564.0,
#   622.0,
#   678.0,
#   760.0,
#   787.0,
#   796.0,
#   920.0]}

# %%
for d,v in repaired_dict.items():
    print(f"{d}: {len(repaired_dict[d])}")
# Out:
# ProviderNumber: 28
# HospitalName: 22
# Address1: 28
# Address2: 0
# Address3: 0
# City: 32
# State: 4
# ZipCode: 28
# CountyName: 38
# PhoneNumber: 30
# HospitalType: 24
# HospitalOwner: 6
# EmergencyService: 0
# Condition: 3
# MeasureCode: 5
# MeasureName: 25
# Score: 52
# Sample: 0
# Stateavg: 35

# %%
repaired_hospital=df_union_before_and_after[df_union_before_and_after['_tid_'].isin(repaired_dict['HospitalOwner'])]

# %%
repaired_hospital[['_tid_','type','ZipCode','HospitalName','PhoneNumber','HospitalOwner','State']].sort_values(by=['_tid_','type']).reset_index()
# Out:
#     index  _tid_          type ZipCode                    HospitalName  \
# 0     226  113.0   after_clean   36467        mizell memorial hospital
# 1     227  113.0  before_clean   36467        mizell memorial hospital
# 2    2113  113.0  ground_truth   36467        mizell memorial hospital
# 3     627  313.0   after_clean   36201  stringfellow memorial hospital
# 4     626  313.0  before_clean   36201  stringfellow memorial hospital
# 5    2313  313.0  ground_truth   36201  stringfellow memorial hospital
# 6     898  449.0   after_clean   99508        alaska regional hospital
# 7     899  449.0  before_clean   99508        alaska regional hospital
# 8    2449  449.0  ground_truth   99508        alaska regional hospital
# 9     987  493.0   after_clean   35960         cherokee medical center
# 10    986  493.0  before_clean   35960         cherokee medical center
# 11   2493  493.0  ground_truth   35960         cherokee medical center
# 12   1568  784.0   after_clean   35801             huntsville hospital
# 13   1569  784.0  before_clean   35801             huntsville hospital
# 14   2784  784.0  ground_truth   35801             huntsville hospital
# 15   1692  846.0   after_clean   35045          chilton medical center
# 16   1693  846.0  before_clean   35045          chilton medical center
# 17   2846  846.0  ground_truth   35045          chilton medical center
#
#    PhoneNumber                                HospitalOwner State
# 0   3344933541               voluntary non-profit - private    al
# 1   3344933541               volunxary non-profix - privaxe    al
# 2   3344933541               voluntary non-profit - private    al
# 3   2562358900                                  proprietary    al
# 4   2562358900                                  prxprietary    al
# 5   2562358900                                  proprietary    al
# 6   9072761131                                  proprietary    ak
# 7   9072761131                                  proxrietary    ak
# 8   9072761131                                  proprietary    ak
# 9   2569275531               voluntary non-profit - private    al
# 10  2569275531               voluntaryxnon-profitx-xprivate    al
# 11  2569275531               voluntary non-profit - private    al
# 12  2562651000  government - hospital district or authority    al
# 13  2562651000  goverxmext - hospital district or authority    al
# 14  2562651000  government - hospital district or authority    al
# 15  2057552500               voluntary non-profit - private    al
# 16  2057552500               voluntaxy non-pxofit - pxivate    al
# 17  2057552500               voluntary non-profit - private    al

# %%
wrong_dict = {x:[] for x in cols}

# %%
# iterate this dataframe to find all wrong predictions and list them to choose
grouped = df_union_before_and_after.groupby('_tid_')
k = 0

for name, group in grouped:
    tid = pd.to_numeric(group.iloc[0]['_tid_'], downcast="integer")
    if(k%100==0):
        print(k)
    for c in cols:
        if((group[group['type']=='after_clean'][c].to_string(index=False)\
           != group[group['type']=='ground_truth'][c].to_string(index=False)\
           ) and (group[group['type']=='after_clean'][c].to_string(index=False)\
           != group[group['type']=='before_clean'][c].to_string(index=False))):
            wrong_dict[c].append(tid)
    k+=1
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
wrong_dict
# Out:
# {'ProviderNumber': [],
#  'HospitalName': [],
#  'Address1': [],
#  'Address2': [],
#  'Address3': [],
#  'City': [],
#  'State': [],
#  'ZipCode': [],
#  'CountyName': [],
#  'PhoneNumber': [],
#  'HospitalType': [],
#  'HospitalOwner': [],
#  'EmergencyService': [],
#  'Condition': [],
#  'MeasureCode': [],
#  'MeasureName': [],
#  'Score': [10.0,
#   34.0,
#   35.0,
#   54.0,
#   95.0,
#   103.0,
#   123.0,
#   126.0,
#   128.0,
#   129.0,
#   132.0,
#   135.0,
#   158.0,
#   163.0,
#   164.0,
#   167.0,
#   168.0,
#   171.0,
#   173.0,
#   330.0,
#   361.0,
#   378.0,
#   390.0,
#   470.0,
#   509.0,
#   511.0,
#   569.0,
#   641.0,
#   683.0,
#   695.0,
#   704.0,
#   718.0,
#   742.0,
#   808.0,
#   834.0,
#   836.0,
#   840.0,
#   844.0,
#   856.0,
#   860.0,
#   862.0,
#   879.0,
#   910.0,
#   940.0,
#   988.0,
#   990.0,
#   997.0],
#  'Sample': [],
#  'Stateavg': [432.0,
#   433.0,
#   435.0,
#   436.0,
#   437.0,
#   438.0,
#   439.0,
#   441.0,
#   442.0,
#   443.0,
#   444.0,
#   445.0,
#   446.0,
#   448.0,
#   449.0,
#   450.0,
#   451.0]}

# %%
wrong_cities=df_union_before_and_after[df_union_before_and_after['_tid_'].isin(wrong_dict['Score'])]

# %%
wrong_cities
# Out:
#                           Address1 Address2 Address3          City  \
# 20    1300 south montgomery avenue      NaN      NaN     sheffield
# 21    1300 south montgomery avenue      NaN      NaN     sheffxeld
# 68          1108 ross clark circle      NaN      NaN        dothan
# 69          1108 ross clark circle      NaN      NaN        dothan
# 70          1108 ross clark circle      NaN      NaN        dothan
# 71          1108 ross clark circle      NaN      NaN        dothan
# 108     2505 u s highway 431 north      NaN      NaN          boaz
# 109     2505 u s highway 431 north      NaN      NaN          boaz
# 190                  702 n main st      NaN      NaN           opp
# 191                  702 n main st      NaN      NaN           opp
# 206                  702 n main st      NaN      NaN           opp
# 207                  702 n main st      NaN      NaN           opp
# 246            101 hospital circle      NaN      NaN       luverne
# 247            101 hospital circle      NaN      NaN       luverne
# 252            101 hospital circle      NaN      NaN       luverne
# 253            101 hospital circle      NaN      NaN       luverne
# 256            101 hospital circle      NaN      NaN       luverne
# 257            101 hospital circle      NaN      NaN       luverne
# 258            101 hospital circle      NaN      NaN       luverne
# 259            101 hospital circle      NaN      NaN       luverne
# 264            101 hospital circle      NaN      NaN       luverne
# 265            101 hospital circle      NaN      NaN       luverne
# 270            101 hospital circle      NaN      NaN       luverne
# 271            101 hospital circle      NaN      NaN       luverne
# 316      201 pine street northwest      NaN      NaN     hartselle
# 317      201 pine street northwest      NaN      NaN     hartselle
# 326      201 pine street northwest      NaN      NaN     hartselle
# 327      201 pine street northwest      NaN      NaN     hartselle
# 328      201 pine street northwest      NaN      NaN     hartselle
# 329      201 pine street northwest      NaN      NaN     hartselle
# ...                            ...      ...      ...           ...
# 2171       8000 alabama highway 69      NaN      NaN  guntersville
# 2173       8000 alabama highway 69      NaN      NaN  guntersville
# 2330              301 east 18th st      NaN      NaN      anniston
# 2361           1530 u s highway 43      NaN      NaN      winfield
# 2378           1530 u s highway 43      NaN      NaN      winfield
# 2390         2451 fillingim street      NaN      NaN        mobile
# 2470              126 hospital ave      NaN      NaN         ozark
# 2509              400 northwood dr      NaN      NaN        centre
# 2511              400 northwood dr      NaN      NaN        centre
# 2569                  4800 48th st      NaN      NaN        valley
# 2641         209 north main street      NaN      NaN       wedowee
# 2683         619 south 19th street      NaN      NaN    birmingham
# 2695           805 friendship road      NaN      NaN     tallassee
# 2704           805 friendship road      NaN      NaN     tallassee
# 2718      1912 alabama highway 157      NaN      NaN       cullman
# 2742  849 south three notch street      NaN      NaN     andalusia
# 2808          1007 goodyear avenue      NaN      NaN       gadsden
# 2834             1010 lay dam road      NaN      NaN       clanton
# 2836             1010 lay dam road      NaN      NaN       clanton
# 2840             1010 lay dam road      NaN      NaN       clanton
# 2844             1010 lay dam road      NaN      NaN       clanton
# 2856    1256 military street south      NaN      NaN      hamilton
# 2860    1256 military street south      NaN      NaN      hamilton
# 2862    1256 military street south      NaN      NaN      hamilton
# 2879      1653 temple avenue north      NaN      NaN       fayette
# 2910        600 south third street      NaN      NaN       gadsden
# 2940                515 miranda st      NaN      NaN     georgiana
# 2988           150 gilbreath drive      NaN      NaN       oneonta
# 2990           150 gilbreath drive      NaN      NaN       oneonta
# 2997           150 gilbreath drive      NaN      NaN       oneonta
#
#                           Condition CountyName EmergencyService  \
# 20                     heart attack  jefferson              yes
# 21                     heart attack  jefferson              yes
# 68                        pneumonia    houston              yes
# 69                        pneumonia    houston              yes
# 70                        pneumonia    houston              yes
# 71                        pneumonia    houston              yes
# 108                   heart failure   marshall              yes
# 109                   heart failure   marshall              yes
# 190                    heart attack  covington               no
# 191                    heart attack  covington               no
# 206                   heart failure  covington               no
# 207                   heart failure  covington               no
# 246                    heart attack   crenshaw              yes
# 247                    heart attack   crenshaw              yes
# 252                   heart failure   crenshaw              yes
# 253                   heart failure   crenshaw              yes
# 256                   heart failure   crenshaw              yes
# 257                   heart failure   crenshaw              yes
# 258                   heart failure   crenshaw              yes
# 259                   heart failure   crenshaw              yes
# 264                       pneumonia   crenshaw              yes
# 265                       pneumonia   crenshaw              yes
# 270                       pneumonia   crenshaw              yes
# 271                       pneumonia   crenshaw              yes
# 316                       pneumonia     morgan              yes
# 317                       pneumonia     morgan              yes
# 326   surgical infection prevention     morgan              yes
# 327   surgical infection prevention     morgan              yes
# 328   surgical infection prevention     morgan              yes
# 329   surgical infection prevention     morgan              yes
# ...                             ...        ...              ...
# 2171                   heart attack   marshall              yes
# 2173                   heart attack   marshall              yes
# 2330  surgical infection prevention    calhoun              yes
# 2361                  heart failure     marion              yes
# 2378  surgical infection prevention     marion              yes
# 2390                      pneumonia     mobile              yes
# 2470                   heart attack       dale              yes
# 2509  surgical infection prevention   cherokee              yes
# 2511  surgical infection prevention   cherokee              yes
# 2569                   heart attack   chambers              yes
# 2641                   heart attack   randolph               no
# 2683  surgical infection prevention  jefferson              yes
# 2695                   heart attack     elmore               no
# 2704                      pneumonia     elmore               no
# 2718                   heart attack    cullman              yes
# 2742                   heart attack  covington               no
# 2808                   heart attack     etowah              yes
# 2834                  heart failure    chilton              yes
# 2836                  heart failure    chilton              yes
# 2840                      pneumonia    chilton              yes
# 2844  surgical infection prevention    chilton              yes
# 2856                   heart attack     marion              yes
# 2860                  heart failure     marion              yes
# 2862                  heart failure     marion              yes
# 2879                   heart attack    fayette              yes
# 2910                   heart attack     etowah              yes
# 2940                  heart failure     butler               no
# 2988                  heart failure     blount              yes
# 2990                  heart failure     blount              yes
# 2997  surgical infection prevention     blount              yes
#
#                               HospitalName  \
# 20          helen keller memorial hospital
# 21          helen keller memorial hospital
# 68        southeast alabama medical center
# 69        southeast alabama medical center
# 70        southeast alabama medical center
# 71        southeast alabama medical center
# 108          marshall medical center south
# 109          marshall medical center south
# 190               mizell memorial hospital
# 191               mizell memorial hospital
# 206               mizell memorial hospital
# 207               mizell memorial hospital
# 246            crenshaw community hospital
# 247            crenshaw community hospital
# 252            crenshaw community hospital
# 253            crenshaw community hospital
# 256            crenshaw community hospital
# 257            crenshaw community hospital
# 258            crenshaw community hospital
# 259            crenshaw community hospital
# 264            crenshaw community hospital
# 265            crenshaw community hospital
# 270            crenshaw community hospital
# 271            crenshaw community hospital
# 316               hartselle medical center
# 317               hartselle medical center
# 326               hartselle medical center
# 327               hartselle medical center
# 328               hartselle medical center
# 329               hartselle medical center
# ...                                    ...
# 2171         marshall medical center north
# 2173         marshall medical center north
# 2330        stringfellow memorial hospital
# 2361              northwest medical center
# 2378              northwest medical center
# 2390  univ of south alabama medical center
# 2470                   dale medical center
# 2509               cherokee medical center
# 2511               cherokee medical center
# 2569          g h lanier memorial hospital
# 2641                      wedowee hospital
# 2683        university of alabama hospital
# 2695                community hospital inc
# 2704                community hospital inc
# 2718       cullman regional medical center
# 2742           andalusia regional hospital
# 2808       gadsden regional medical center
# 2834                chilton medical center
# 2836                chilton medical center
# 2840                chilton medical center
# 2844                chilton medical center
# 2856        marion regional medical center
# 2860        marion regional medical center
# 2862        marion regional medical center
# 2879                fayette medical center
# 2910     riverview regional medical center
# 2940                    georgiana hospital
# 2988                    st vincents blount
# 2990                    st vincents blount
# 2997                    st vincents blount
#
#                                     HospitalOwner          HospitalType  ...  \
# 20    government - hospital district or authority  acute care hospitals  ...
# 21    government - hospital district or authority  acute care hospitals  ...
# 68    government - hospital district or authority  acute care hospitals  ...
# 69    government - hospital district or authority  acute care hospitals  ...
# 70    government - hospital district or authority  acute care hospitals  ...
# 71    government - hospital district or authority  acute care hospitals  ...
# 108   government - hospital district or authority  acute care hospitals  ...
# 109   government - hospital district or authority  acute care hospitals  ...
# 190                voluntary non-profit - private  acute care hospitals  ...
# 191                voluntary non-profit - private  acute care hospitals  ...
# 206                voluntary non-profit - private  acute care hospitals  ...
# 207                voluntary non-profit - private  acute care hospitals  ...
# 246                          government - federal  acute care hospitals  ...
# 247                          government - federal  acute care hospitals  ...
# 252                          government - federal  acute care hospitals  ...
# 253                          government - federal  acute care hospitals  ...
# 256                          government - federal  acute care hospitals  ...
# 257                          government - federal  acute care hospitals  ...
# 258                          government - federal  acute care hospitals  ...
# 259                          government - federal  acute care hospitals  ...
# 264                          government - federal  acute care hospitals  ...
# 265                          government - federal  acute care hospitals  ...
# 270                          government - federal  acute care hospitals  ...
# 271                          government - federal  acute care hospitals  ...
# 316                                   proprietary  acute care hospitals  ...
# 317                                   proprietary  acute care hospitals  ...
# 326                                   proprietary  acute care hospitals  ...
# 327                                   proprietary  acute care hospitals  ...
# 328                                   pxopxietaxy  acute care hospitals  ...
# 329                                   pxopxietaxy  acute care hospitals  ...
# ...                                           ...                   ...  ...
# 2171  government - hospital district or authority  acute care hospitals  ...
# 2173  government - hospital district or authority  acute care hospitals  ...
# 2330                                  proprietary  acute care hospitals  ...
# 2361                                  proprietary  acute care hospitals  ...
# 2378                                  proprietary  acute care hospitals  ...
# 2390                           government - state  acute care hospitals  ...
# 2470  government - hospital district or authority  acute care hospitals  ...
# 2509               voluntary non-profit - private  acute care hospitals  ...
# 2511               voluntary non-profit - private  acute care hospitals  ...
# 2569                 voluntary non-profit - other  acute care hospitals  ...
# 2641                           government - local  acute care hospitals  ...
# 2683                           government - state  acute care hospitals  ...
# 2695               voluntary non-profit - private  acute care hospitals  ...
# 2704               voluntary non-profit - private  acute care hospitals  ...
# 2718  government - hospital district or authority  acute care hospitals  ...
# 2742                                  proprietary  acute care hospitals  ...
# 2808                                  proprietary  acute care hospitals  ...
# 2834               voluntary non-profit - private  acute care hospitals  ...
# 2836               voluntary non-profit - private  acute care hospitals  ...
# 2840               voluntary non-profit - private  acute care hospitals  ...
# 2844               voluntary non-profit - private  acute care hospitals  ...
# 2856               voluntary non-profit - private  acute care hospitals  ...
# 2860               voluntary non-profit - private  acute care hospitals  ...
# 2862               voluntary non-profit - private  acute care hospitals  ...
# 2879                 voluntary non-profit - other  acute care hospitals  ...
# 2910                                  proprietary  acute care hospitals  ...
# 2940               voluntary non-profit - private  acute care hospitals  ...
# 2988               voluntary non-profit - private  acute care hospitals  ...
# 2990               voluntary non-profit - private  acute care hospitals  ...
# 2997               voluntary non-profit - private  acute care hospitals  ...
#
#                                             MeasureName PhoneNumber  \
# 20    heart attack patients given ace inhibitor or a...  2563864556
# 21    heart attack patients given ace inhibitor or a...  2563864556
# 68    pneumonia patients given the most appropriate ...  3347938701
# 69    pneumonia patients given the most appropriate ...  3347938701
# 70    pneumonia patients assessed and given influenz...  3347938701
# 71    pneumonia patients assessed and given influenz...  3347938701
# 108   heart failure patients given smoking cessation...  2565938310
# 109   heart failure patients given smoking cessation...  2565938310
# 190    heart attack patients given aspirin at discharge  3344933541
# 191    heart attack patients given aspirin at discharge  3344933541
# 206   heart failure patients given ace inhibitor or ...  3344933541
# 207   heart failure patients given ace inhibitor or ...  3344933541
# 246   heart attack patients given beta blocker at di...  3343353374
# 247   heart attack patients given beta blocker at di...  3343353374
# 252   heart failure patients given discharge instruc...  3343353374
# 253   heart failure patients given discharge instruc...  3343353374
# 256   heart failure patients given ace inhibitor or ...  3343353374
# 257   heart failure patients given ace inhibitor or ...  3343353374
# 258   heart failure patients given smoking cessation...  3343353374
# 259   heart failure patients given smoking cessation...  3343353374
# 264   pneumonia patients given smoking cessation adv...  3343353374
# 265   pneumonia patients given smoking cessation adv...  3343353374
# 270   pneumonia patients assessed and given influenz...  3343353374
# 271   pneumonia patients assessed and given influenz...  3343353374
# 316   pneumonia patients given initial antibiotic(s)...  2567736511
# 317   pneumonia patients given initial antibiotic(s)...  2567736511
# 326   surgery patients who were given the  right kin...  2567736511
# 327   surgery patients who were given the  right kin...  2567736511
# 328   surgery patients whose preventive antibiotics ...  2567736511
# 329   surgery patients whose preventive antibiotics ...  2567736511
# ...                                                 ...         ...
# 2171  heart attack patients given ace inhibitor or a...  2565718000
# 2173  heart attack patients given beta blocker at di...  2565718000
# 2330  surgery patients who were taking heart drugs c...  2562358900
# 2361  heart failure patients given discharge instruc...  2054877736
# 2378  patients who got treatment  at the right time ...  2054877736
# 2390  pneumonia patients assessed and given pneumoco...  2514717110
# 2470  heart attack patients given beta blocker at di...  3347742601
# 2509  surgery patients who were given an antibiotic ...  2569275531
# 2511  surgery patients whose preventive antibiotics ...  2569275531
# 2569  heart attack patients given smoking cessation ...  3347561400
# 2641     heart attack patients given aspirin at arrival  2563572111
# 2683  surgery patients who were taking heart drugs c...  2059344011
# 2695  heart attack patients given beta blocker at di...  3342836541
# 2704  pneumonia patients given smoking cessation adv...  3342836541
# 2718  heart attack patients given ace inhibitor or a...  2567372000
# 2742   heart attack patients given aspirin at discharge  3342228466
# 2808  heart attack patients given pci within 90 minu...  2564944000
# 2834  heart failure patients given discharge instruc...  2057552500
# 2836  heart failure patients given ace inhibitor or ...  2057552500
# 2840  pneumonia patients given smoking cessation adv...  2057552500
# 2844  surgery patients who were taking heart drugs c...  2057552500
# 2856  heart attack patients given beta blocker at di...  2059216200
# 2860  heart failure patients given an evaluation of ...  2059216200
# 2862  heart failure patients given smoking cessation...  2059216200
# 2879  heart attack patients given ace inhibitor or a...  2059325966
# 2910  heart attack patients given fibrinolytic medic...  2565435200
# 2940  heart failure patients given smoking cessation...  3343762205
# 2988  heart failure patients given an evaluation of ...  2052743000
# 2990  heart failure patients given smoking cessation...  2052743000
# 2997  surgery patients who were taking heart drugs c...  2052743000
#
#      ProviderNumber        Sample Score State        Stateavg ZipCode  _tid_  \
# 20            10019    4 patients  100%    al        al_ami-3   35660   10.0
# 21            10019    4 patients   75%    al        al_ami-3   35660   10.0
# 68            10001  147 patients  100%    al         al_pn-6   36302   34.0
# 69            10001  147 patients   80%    al         al_pn-6   36302   34.0
# 70            10001  160 patients   99%    al         al_pn-7   36302   35.0
# 71            10001  160 patients   84%    al         al_pn-7   36302   35.0
# 108           10005   34 patients   94%    al         al_hf-4   35957   54.0
# 109           10005   34 patients  100%    al         al_hf-4   35957   54.0
# 190           10007    2 patients  100%    al        al_ami-2   36467   95.0
# 191           10007    2 patients   50%    al        al_ami-2   36467   95.0
# 206           10007   14 patients  100%    al         al_hf-3   36467  103.0
# 207           10007   14 patients   64%    al         al_hf-3   36467  103.0
# 246           10008    1 patients    0%    al        al_ami-5   36049  123.0
# 247           10008    1 patients  100%    al        al_ami-5   36049  123.0
# 252           10008   26 patients  100%    al         al_hf-1   36049  126.0
# 253           10008   26 patients    4%    al         al_hf-1   36049  126.0
# 256           10008    8 patients   75%    al         al_hf-3   36049  128.0
# 257           10008    8 patients  100%    al         al_hf-3   36049  128.0
# 258           10008    5 patients    0%    al         al_hf-4   36049  129.0
# 259           10008    5 patients  100%    al         al_hf-4   36049  129.0
# 264           10008    9 patients  100%    al         al_pn-4   36049  132.0
# 265           10008    9 patients   33%    al         al_pn-4   36049  132.0
# 270           10008   15 patients   47%    al         al_pn-7   36049  135.0
# 271           10008   15 patients  100%    al         al_pn-7   36049  135.0
# 316           10009   51 patients   9x%    al        al_pn-5c   35640  158.0
# 317           10009   51 patients  100%    al        al_pn-5c   35640  158.0
# 326           10009    7 patients  100%    al   al_scip-inf-2   35640  163.0
# 327           10009    7 patients   x7%    al   al_scip-inf-2   35640  163.0
# 328           10009    5 patients  100%    al   al_scip-inf-3   35640  164.0
# 329           10009    5 patients   80%    al   al_scip-inf-3   35640  164.0
# ...             ...           ...   ...   ...             ...     ...    ...
# 2171          10010    2 patients   50%    al        al_ami-3   35976  171.0
# 2173          10010    6 patients   83%    al        al_ami-5   35976  173.0
# 2330          10038   23 patients   83%    al  al_scip-card-2   36201  330.0
# 2361          10086   48 patients   90%    al         al_hf-1   35594  361.0
# 2378          10086   58 patients   95%    al   al_scip-vte-2   35594  378.0
# 2390          10087    7 patients   71%    al         al_pn-2   36617  390.0
# 2470          10021    6 patients   83%    al        al_ami-5   36360  470.0
# 2509          10022    2 patients    0%    al   al_scip-inf-1   35960  509.0
# 2511          10022    1 patients    0%    al   al_scip-inf-3   35960  511.0
# 2569          10025    4 patients   50%    al        al_ami-4   36854  569.0
# 2641          10032    4 patients   50%    al        al_ami-1   36278  641.0
# 2683          10033   94 patients   69%    al  al_scip-card-2   35233  683.0
# 2695          10034    4 patients   75%    al        al_ami-5   36078  695.0
# 2704          10034   41 patients   90%    al         al_pn-4   36078  704.0
# 2718          10035    3 patients   67%    al        al_ami-3   35058  718.0
# 2742          10036    5 patients   60%    al        al_ami-2   36420  742.0
# 2808          10040   12 patients   83%    al       al_ami-8a   35903  808.0
# 2834          10043   19 patients   84%    al         al_hf-1   35045  834.0
# 2836          10043    4 patients   75%    al         al_hf-3   35045  836.0
# 2840          10043   16 patients   94%    al         al_pn-4   35045  840.0
# 2844          10043    2 patients   50%    al  al_scip-card-2   35045  844.0
# 2856          10044    3 patients   33%    al        al_ami-5   35570  856.0
# 2860          10044   46 patients   80%    al         al_hf-2   35570  860.0
# 2862          10044   10 patients   80%    al         al_hf-4   35570  862.0
# 2879          10045    1 patients    0%    al        al_ami-3   35555  879.0
# 2910          10046    8 patients   88%    al       al_ami-7a   35901  910.0
# 2940          10047    8 patients   75%    al         al_hf-4   36033  940.0
# 2988          10050   34 patients   85%    al         al_hf-2   35121  988.0
# 2990          10050    7 patients   43%    al         al_hf-4   35121  990.0
# 2997          10050    8 patients   25%    al  al_scip-card-2   35121  997.0
#
#               type
# 20     after_clean
# 21    before_clean
# 68     after_clean
# 69    before_clean
# 70     after_clean
# 71    before_clean
# 108   before_clean
# 109    after_clean
# 190    after_clean
# 191   before_clean
# 206    after_clean
# 207   before_clean
# 246   before_clean
# 247    after_clean
# 252    after_clean
# 253   before_clean
# 256   before_clean
# 257    after_clean
# 258   before_clean
# 259    after_clean
# 264    after_clean
# 265   before_clean
# 270   before_clean
# 271    after_clean
# 316   before_clean
# 317    after_clean
# 326    after_clean
# 327   before_clean
# 328    after_clean
# 329   before_clean
# ...            ...
# 2171  ground_truth
# 2173  ground_truth
# 2330  ground_truth
# 2361  ground_truth
# 2378  ground_truth
# 2390  ground_truth
# 2470  ground_truth
# 2509  ground_truth
# 2511  ground_truth
# 2569  ground_truth
# 2641  ground_truth
# 2683  ground_truth
# 2695  ground_truth
# 2704  ground_truth
# 2718  ground_truth
# 2742  ground_truth
# 2808  ground_truth
# 2834  ground_truth
# 2836  ground_truth
# 2840  ground_truth
# 2844  ground_truth
# 2856  ground_truth
# 2860  ground_truth
# 2862  ground_truth
# 2879  ground_truth
# 2910  ground_truth
# 2940  ground_truth
# 2988  ground_truth
# 2990  ground_truth
# 2997  ground_truth
#
# [141 rows x 21 columns]

# %%
wrong_cities.sort_values(by=['_tid_','type','HospitalOwner'], inplace=True)

# %%
wrong_cities[['HospitalOwner','HospitalName', '_tid_', 'type']]

# %%
wrong_dict

# %%
wrong_dict['City']

# %%
df_union_before_and_after

# %%
wrong_cities

# %%
conn.close()

# %% [markdown]
# ### given an attribute and a tid (row id), find responsible rule(s)

# %%
# import hc_responsibility
# hc_responsibility.rule_responsibility(attr_name='PhoneNumber', tid=381)

# %%
# conn = psycopg2.connect(dbname="holo", user="holocleanuser", password="abcd1234")

# %% [markdown]
# ### result after deleting
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.PhoneNumber,t2.PhoneNumber)
#     AND
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ZipCode,t2.ZipCode)
#
# fixing using :
#
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)
#     AND
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.State,t2.State)

# %%
# q_2 = """
# select * from hospital_repaired_2 where "Address1" = '2451 fillingim street'
# """
# df_repaired_2 = pd.read_sql(q_2, conn)

# %%
# df_repaired_2

# %% [markdown]
# ### result after deleting
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.State,t2.State)
#     fixing using :
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.PhoneNumber,t2.PhoneNumber)
#     AND
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ZipCode,t2.ZipCode)
#     AND
#     t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)

# %%
# q_6 = """
# select * from hospital_repaired_6 where "Address1" = '2451 fillingim street'
# """
# df_repaired_6 = pd.read_sql(q_6, conn)

# %%
# df_repaired_6
